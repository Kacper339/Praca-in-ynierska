# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage.transform import resize

from tensorflow.keras import datasets, layers, models, callbacks
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
# Out:
# C:\Users\Kacper\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 1. Wstępne przetwarzanie danych

# %%
train_dir = "seg_train\seg_train"
test_dir = "seg_test\seg_test"

x_train = []
y_train = []

x_test = []
y_test = []

folderlist = os.listdir(train_dir);
folderlist.sort();

print(folderlist)

for i in range(0,6):
    print("     "+str(i)+"    ",end="")
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']
#      0         1         2         3         4         5

# %%
for i, category in enumerate(folderlist):
    pictures = os.listdir(train_dir+"/"+category)
    for picture in pictures:
        img = plt.imread(train_dir+"/"+category+'/{0}'.format(picture),0)
        img_resized = resize(img, (228, 228))  # Zmiana rozmiaru obrazów
        x_train.append(img_resized)
        y_train.append(i)

print("Train data:")
print("x_train: "+str(len(x_train))) 
print("y_train: "+str(len(y_train)))
# Out:
# Train data:
# x_train: 14034
# y_train: 14034

# %%
for i, category in enumerate(folderlist):
    pictures = os.listdir(test_dir+"/"+category)
    for picture in pictures:
        img = plt.imread(test_dir+"/"+category+'/{0}'.format(picture),0)
        img_resized = resize(img, (228, 228))  # Zmiana rozmiaru obrazów
        x_test.append(img_resized)
        y_test.append(i)

print("Test data:")
print("x_test: "+str(len(x_test)))
print("y_test: "+str(len(y_test)))
# Out:
# Test data:
# x_test: 3000
# y_test: 3000

# %%
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

print(x_train.shape)
# Out:
# (14034, 228, 228, 3)

# %%
x_train_norm = (x_train - np.min(x_train)) / (np.max(x_train) - np.min(x_train)) * 255.0
x_train_norm = x_train_norm / 255.0

x_test_norm = (x_test - np.min(x_test)) / (np.max(x_test) - np.min(x_test)) * 255.0
x_test_norm = x_test_norm / 255.0

# %%
y_train_oneHot = to_categorical(y_train, num_classes=6)
y_test_oneHot = to_categorical(y_test,num_classes=6)

# %% [markdown]
# # 2. Tworzenie modeli z ewentualną modyfikacją danych

# %% [markdown]
# ## 2.1 Model Prosty

# %%
model_simple = models.Sequential()
model_simple.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_simple.add(layers.MaxPooling2D((2, 2)))

model_simple.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_simple.add(layers.Dropout(0.4))
model_simple.add(layers.MaxPooling2D((2, 2)))

model_simple.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_simple.add(layers.Dropout(0.4))
model_simple.add(layers.MaxPooling2D((2, 2)))

model_simple.add(layers.Flatten())
model_simple.add(layers.Dense(512, activation='relu'))
model_simple.add(layers.Dropout(0.4))
model_simple.add(layers.Dense(len(folderlist), activation='softmax'))

model_simple.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
batchSize = 32
epochsNum = 30

stopEarly = EarlyStopping(monitor='val_accuracy' , patience=5, restore_best_weights=True)

history_simple = model_simple.fit(x_train_norm,
                   y_train_oneHot,
                   batch_size=batchSize,
                   shuffle=True,
                   epochs=epochsNum,
                   validation_data=(x_test_norm, y_test_oneHot),
                   callbacks=[stopEarly])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 439/439 [==============================] - 145s 326ms/step - loss: 1.0316 - accuracy: 0.6094 - val_loss: 0.8753 - val_accuracy: 0.7427
# Epoch 2/30
# 439/439 [==============================] - 141s 321ms/step - loss: 0.6566 - accuracy: 0.7600 - val_loss: 0.7026 - val_accuracy: 0.7947
# Epoch 3/30
# 439/439 [==============================] - 137s 312ms/step - loss: 0.5191 - accuracy: 0.8127 - val_loss: 0.6245 - val_accuracy: 0.8033
# Epoch 4/30
# 439/439 [==============================] - 137s 313ms/step - loss: 0.4205 - accuracy: 0.8502 - val_loss: 0.5562 - val_accuracy: 0.8233
# Epoch 5/30
# 439/439 [==============================] - 137s 311ms/step - loss: 0.3267 - accuracy: 0.8799 - val_loss: 0.5168 - val_accuracy: 0.8273
# Epoch 6/30
# 439/439 [==============================] - 136s 310ms/step - loss: 0.2464 - accuracy: 0.9126 - val_loss: 0.5027 - val_accuracy: 0.8413
# Epoch 7/30
# 439/439 [==============================] - 136s 310ms/step - loss: 0.2050 - accuracy: 0.9245 - val_loss: 0.5550 - val_accuracy: 0.7993
# Epoch 8/30
# 439/439 [==============================] - 136s 310ms/step - loss: 0.1678 - accuracy: 0.9438 - val_loss: 0.5585 - val_accuracy: 0.8030
# Epoch 9/30
# 439/439 [==============================] - 137s 312ms/step - loss: 0.1474 - accuracy: 0.9505 - val_loss: 0.5246 - val_accuracy: 0.8350
# Epoch 10/30
# 439/439 [==============================] - 136s 311ms/step - loss: 0.1129 - accuracy: 0.9592 - val_loss: 0.5529 - val_accuracy: 0.8307
# Epoch 11/30
# 439/439 [==============================] - 136s 310ms/step - loss: 0.1146 - accuracy: 0.9617 - val_loss: 0.5442 - val_accuracy: 0.8327

# %%
model_simple.save("zapisane/model_simple.h5")
model_simple.save("zapisane/model_simple.keras")
# Out:
# C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 2.2 Model prosty z dodatkową warstwą i innymi parametrami

# %%
model_bigger = models.Sequential()
model_bigger.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_bigger.add(layers.MaxPooling2D((2, 2)))

model_bigger.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_bigger.add(layers.MaxPooling2D((2, 2)))
model_bigger.add(layers.Dropout(0.3))

model_bigger.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_bigger.add(layers.MaxPooling2D((2, 2)))
model_bigger.add(layers.Dropout(0.3))

model_bigger.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_bigger.add(layers.MaxPooling2D((2, 2)))
model_bigger.add(layers.Dropout(0.3))

model_bigger.add(layers.Flatten())
model_bigger.add(layers.Dense(512, activation='relu'))
model_bigger.add(layers.Dropout(0.4))
model_bigger.add(layers.Dense(6, activation='softmax'))

model_bigger.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
batchSize = 32
epochsNum = 50

stopEarly = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history_bigger = model_bigger.fit(x_train_norm,
                           y_train_oneHot,
                           batch_size=batchSize,
                           shuffle=True,
                            epochs=epochsNum,
                            validation_data=(x_test_norm, y_test_oneHot),
                            callbacks=[stopEarly])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 439/439 [==============================] - 91s 204ms/step - loss: 1.1733 - accuracy: 0.5335 - val_loss: 0.9956 - val_accuracy: 0.6440
# Epoch 2/50
# 439/439 [==============================] - 88s 200ms/step - loss: 0.8713 - accuracy: 0.6717 - val_loss: 0.8433 - val_accuracy: 0.6990
# Epoch 3/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.7579 - accuracy: 0.7189 - val_loss: 0.8691 - val_accuracy: 0.6963
# Epoch 4/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.6850 - accuracy: 0.7493 - val_loss: 0.7339 - val_accuracy: 0.7193
# Epoch 5/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.6341 - accuracy: 0.7694 - val_loss: 0.7287 - val_accuracy: 0.7353
# Epoch 6/50
# 439/439 [==============================] - 88s 200ms/step - loss: 0.5920 - accuracy: 0.7825 - val_loss: 0.6013 - val_accuracy: 0.7940
# Epoch 7/50
# 439/439 [==============================] - 89s 203ms/step - loss: 0.5533 - accuracy: 0.8013 - val_loss: 0.5466 - val_accuracy: 0.8143
# Epoch 8/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.5279 - accuracy: 0.8085 - val_loss: 0.5643 - val_accuracy: 0.8027
# Epoch 9/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.5054 - accuracy: 0.8211 - val_loss: 0.5196 - val_accuracy: 0.8180
# Epoch 10/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.4809 - accuracy: 0.8246 - val_loss: 0.4930 - val_accuracy: 0.8330
# Epoch 11/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.4581 - accuracy: 0.8355 - val_loss: 0.4849 - val_accuracy: 0.8283
# Epoch 12/50
# 439/439 [==============================] - 87s 199ms/step - loss: 0.4397 - accuracy: 0.8412 - val_loss: 0.4799 - val_accuracy: 0.8263
# Epoch 13/50
# 439/439 [==============================] - 88s 200ms/step - loss: 0.4255 - accuracy: 0.8450 - val_loss: 0.4456 - val_accuracy: 0.8450
# Epoch 14/50
# 439/439 [==============================] - 89s 204ms/step - loss: 0.4180 - accuracy: 0.8509 - val_loss: 0.4976 - val_accuracy: 0.8200
# Epoch 15/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.3983 - accuracy: 0.8581 - val_loss: 0.4683 - val_accuracy: 0.8397
# Epoch 16/50
# 439/439 [==============================] - 88s 202ms/step - loss: 0.3758 - accuracy: 0.8637 - val_loss: 0.5000 - val_accuracy: 0.8153
# Epoch 17/50
# 439/439 [==============================] - 89s 203ms/step - loss: 0.3689 - accuracy: 0.8689 - val_loss: 0.4451 - val_accuracy: 0.8443
# Epoch 18/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.3511 - accuracy: 0.8737 - val_loss: 0.4163 - val_accuracy: 0.8547
# Epoch 19/50
# 439/439 [==============================] - 89s 202ms/step - loss: 0.3365 - accuracy: 0.8799 - val_loss: 0.4222 - val_accuracy: 0.8477
# Epoch 20/50
# 439/439 [==============================] - 90s 205ms/step - loss: 0.3219 - accuracy: 0.8853 - val_loss: 0.3961 - val_accuracy: 0.8610
# Epoch 21/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.3118 - accuracy: 0.8866 - val_loss: 0.4545 - val_accuracy: 0.8363
# Epoch 22/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.2915 - accuracy: 0.8935 - val_loss: 0.4069 - val_accuracy: 0.8590
# Epoch 23/50
# 439/439 [==============================] - 89s 202ms/step - loss: 0.2741 - accuracy: 0.9039 - val_loss: 0.4083 - val_accuracy: 0.8533
# Epoch 24/50
# 439/439 [==============================] - 89s 203ms/step - loss: 0.2660 - accuracy: 0.9025 - val_loss: 0.4342 - val_accuracy: 0.8487
# Epoch 25/50
# 439/439 [==============================] - 89s 202ms/step - loss: 0.2552 - accuracy: 0.9080 - val_loss: 0.4220 - val_accuracy: 0.8490
# Epoch 26/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.2482 - accuracy: 0.9111 - val_loss: 0.4571 - val_accuracy: 0.8393
# Epoch 27/50
# 439/439 [==============================] - 89s 202ms/step - loss: 0.2369 - accuracy: 0.9154 - val_loss: 0.4200 - val_accuracy: 0.8570
# Epoch 28/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.2173 - accuracy: 0.9224 - val_loss: 0.4762 - val_accuracy: 0.8313
# Epoch 29/50
# 439/439 [==============================] - 88s 201ms/step - loss: 0.2038 - accuracy: 0.9246 - val_loss: 0.4551 - val_accuracy: 0.8520
# Epoch 30/50
# 439/439 [==============================] - 90s 204ms/step - loss: 0.2044 - accuracy: 0.9256 - val_loss: 0.4461 - val_accuracy: 0.8497

# %%
model_bigger.save("zapisane/model_bigger.h5")
model_bigger.save("zapisane/model_bigger.keras")
# Out:
# C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 2.3 Model z modyfikacją zdjęć

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

datagen.fit(x_train)

# %%
model_modify = models.Sequential()

model_modify.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_modify.add(layers.MaxPooling2D((2, 2)))

model_modify.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_modify.add(layers.Dropout(0.3))
model_modify.add(layers.MaxPooling2D((2, 2)))

model_modify.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_modify.add(layers.Dropout(0.3))
model_modify.add(layers.MaxPooling2D((2, 2)))

model_modify.add(layers.Flatten())
model_modify.add(layers.Dense(512, activation='relu'))
model_modify.add(layers.Dropout(0.3))
model_modify.add(layers.Dense(len(folderlist), activation='softmax'))

model_modify.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
batchSize = 32
epochsNum = 65

stopEarly = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Trening modelu
history_modify = model_modify.fit(datagen.flow(x_train_norm, y_train_oneHot, batch_size=32),
                           shuffle=True,
                            epochs=epochsNum,
                            validation_data=(x_test, y_test_oneHot),
                            callbacks=[stopEarly])
# Out:
# Epoch 1/65
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 439/439 [==============================] - 156s 353ms/step - loss: 1.0871 - accuracy: 0.5963 - val_loss: 0.9977 - val_accuracy: 0.6523
# Epoch 2/65
# 439/439 [==============================] - 149s 340ms/step - loss: 0.7624 - accuracy: 0.7165 - val_loss: 0.7620 - val_accuracy: 0.7357
# Epoch 3/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.6655 - accuracy: 0.7567 - val_loss: 0.6963 - val_accuracy: 0.7427
# Epoch 4/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.5981 - accuracy: 0.7842 - val_loss: 0.5709 - val_accuracy: 0.8203
# Epoch 5/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.5496 - accuracy: 0.8014 - val_loss: 0.6667 - val_accuracy: 0.7657
# Epoch 6/65
# 439/439 [==============================] - 148s 336ms/step - loss: 0.5117 - accuracy: 0.8160 - val_loss: 0.4845 - val_accuracy: 0.8447
# Epoch 7/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.4878 - accuracy: 0.8273 - val_loss: 0.4974 - val_accuracy: 0.8410
# Epoch 8/65
# 439/439 [==============================] - 147s 333ms/step - loss: 0.4720 - accuracy: 0.8313 - val_loss: 0.4553 - val_accuracy: 0.8480
# Epoch 9/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.4406 - accuracy: 0.8406 - val_loss: 0.4693 - val_accuracy: 0.8413
# Epoch 10/65
# 439/439 [==============================] - 147s 334ms/step - loss: 0.4334 - accuracy: 0.8444 - val_loss: 0.4937 - val_accuracy: 0.8370
# Epoch 11/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.4202 - accuracy: 0.8494 - val_loss: 0.4303 - val_accuracy: 0.8570
# Epoch 12/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.3928 - accuracy: 0.8579 - val_loss: 0.3977 - val_accuracy: 0.8627
# Epoch 13/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3846 - accuracy: 0.8628 - val_loss: 0.4060 - val_accuracy: 0.8593
# Epoch 14/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.3773 - accuracy: 0.8634 - val_loss: 0.4240 - val_accuracy: 0.8597
# Epoch 15/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3713 - accuracy: 0.8679 - val_loss: 0.4434 - val_accuracy: 0.8553
# Epoch 16/65
# 439/439 [==============================] - 145s 331ms/step - loss: 0.3653 - accuracy: 0.8723 - val_loss: 0.3755 - val_accuracy: 0.8717
# Epoch 17/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.3436 - accuracy: 0.8774 - val_loss: 0.4091 - val_accuracy: 0.8633
# Epoch 18/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3453 - accuracy: 0.8760 - val_loss: 0.4179 - val_accuracy: 0.8590
# Epoch 19/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3370 - accuracy: 0.8800 - val_loss: 0.4598 - val_accuracy: 0.8363
# Epoch 20/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3368 - accuracy: 0.8799 - val_loss: 0.3765 - val_accuracy: 0.8787
# Epoch 21/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3218 - accuracy: 0.8832 - val_loss: 0.4248 - val_accuracy: 0.8587
# Epoch 22/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.3192 - accuracy: 0.8861 - val_loss: 0.3837 - val_accuracy: 0.8680
# Epoch 23/65
# 439/439 [==============================] - 147s 334ms/step - loss: 0.3055 - accuracy: 0.8880 - val_loss: 0.3608 - val_accuracy: 0.8767
# Epoch 24/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3050 - accuracy: 0.8889 - val_loss: 0.4088 - val_accuracy: 0.8560
# Epoch 25/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.3004 - accuracy: 0.8883 - val_loss: 0.3926 - val_accuracy: 0.8567
# Epoch 26/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.2978 - accuracy: 0.8930 - val_loss: 0.4259 - val_accuracy: 0.8597
# Epoch 27/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.2966 - accuracy: 0.8920 - val_loss: 0.3679 - val_accuracy: 0.8740
# Epoch 28/65
# 439/439 [==============================] - 146s 331ms/step - loss: 0.2867 - accuracy: 0.8955 - val_loss: 0.3749 - val_accuracy: 0.8760
# Epoch 29/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.2800 - accuracy: 0.8965 - val_loss: 0.3865 - val_accuracy: 0.8697
# Epoch 30/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.2837 - accuracy: 0.8972 - val_loss: 0.4363 - val_accuracy: 0.8453
# Epoch 31/65
# 439/439 [==============================] - 146s 333ms/step - loss: 0.2742 - accuracy: 0.9025 - val_loss: 0.3792 - val_accuracy: 0.8713
# Epoch 32/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.2786 - accuracy: 0.9012 - val_loss: 0.3788 - val_accuracy: 0.8780
# Epoch 33/65
# 439/439 [==============================] - 146s 332ms/step - loss: 0.2700 - accuracy: 0.9037 - val_loss: 0.4349 - val_accuracy: 0.8523

# %%
model_modify.save("zapisane/model_modify.h5")
model_modify.save("zapisane/model_modify.keras")
# Out:
# C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 2.4 Model z modyfikacją zdjęć i warstwą BatchNormalization // na razie nie ruszać - za duża wartość val_loss

# %%
model_modify_batch = models.Sequential()

model_modify_batch.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_modify_batch.add(layers.BatchNormalization())
model_modify_batch.add(layers.MaxPooling2D((2, 2)))

model_modify_batch.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_modify_batch.add(layers.Dropout(0.3))
model_modify_batch.add(layers.BatchNormalization())
model_modify_batch.add(layers.MaxPooling2D((2, 2)))

model_modify_batch.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_modify_batch.add(layers.Dropout(0.3))
model_modify_batch.add(layers.BatchNormalization())
model_modify_batch.add(layers.MaxPooling2D((2, 2)))

model_modify_batch.add(layers.Flatten())
model_modify_batch.add(layers.Dense(512, activation='relu'))
model_modify_batch.add(layers.Dropout(0.3))
model_modify_batch.add(layers.BatchNormalization())
model_modify_batch.add(layers.Dense(6, activation='softmax'))

model_modify_batch.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
batchSize = 32
epochsNum = 50

stopEarly = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Trening modelu
history = model_modify_batch.fit(datagen.flow(x_train_norm, y_train_oneHot, batch_size=32),
                           shuffle=True,
                            epochs=epochsNum,
                            validation_data=(x_test, y_test_oneHot),
                            callbacks=[stopEarly])
# Out:
# Epoch 1/50
# 439/439 [==============================] - 187s 423ms/step - loss: 0.9601 - accuracy: 0.6556 - val_loss: 1.8843 - val_accuracy: 0.4697
# Epoch 2/50
# 439/439 [==============================] - 187s 426ms/step - loss: 0.7342 - accuracy: 0.7302 - val_loss: 0.9583 - val_accuracy: 0.6903
# Epoch 3/50
# 439/439 [==============================] - 188s 429ms/step - loss: 0.6396 - accuracy: 0.7650 - val_loss: 0.8051 - val_accuracy: 0.7067
# Epoch 4/50
# 439/439 [==============================] - 189s 429ms/step - loss: 0.5526 - accuracy: 0.8031 - val_loss: 0.7089 - val_accuracy: 0.7500
# Epoch 5/50
# 439/439 [==============================] - 188s 427ms/step - loss: 0.5488 - accuracy: 0.8007 - val_loss: 0.6939 - val_accuracy: 0.7380
# Epoch 6/50
# 439/439 [==============================] - 188s 428ms/step - loss: 0.5153 - accuracy: 0.8175 - val_loss: 0.7967 - val_accuracy: 0.7197
# Epoch 7/50
# 439/439 [==============================] - 190s 432ms/step - loss: 0.4910 - accuracy: 0.8238 - val_loss: 1.1268 - val_accuracy: 0.6487
# Epoch 8/50
# 439/439 [==============================] - 186s 424ms/step - loss: 0.4457 - accuracy: 0.8413 - val_loss: 0.5458 - val_accuracy: 0.8337
# Epoch 9/50
# 439/439 [==============================] - 187s 425ms/step - loss: 0.4643 - accuracy: 0.8314 - val_loss: 0.7213 - val_accuracy: 0.7700
# Epoch 10/50
# 138/439 [========>.....................] - ETA: 2:02 - loss: 0.4005 - accuracy: 0.8551
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2364/1624523546.py in <module>
#       5
#       6 # Trening modelu
# ----> 7 history = model_modify_batch.fit(datagen.flow(x_train_norm, y_train_oneHot, batch_size=32),
#       8                            shuffle=True,
#       9                             epochs=epochsNum,
#
# ~\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\src\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model_modify_batch.save("zapisane/model_modify_batch.h5")
model_modify_batch.save("zapisane/model_modify_batch.keras")

# %% [markdown]
# ## 2.5 Model prosty wykorzystujący Transformatę Fouriera

# %%
x_train_gray = np.mean(x_train_norm, axis=-1)
x_test_gray = np.mean(x_test_norm, axis=-1)

def fft_batch(images, batch_size=100):
    fft_images = []
    for i in range(0, len(images), batch_size):
        batch = images[i:i + batch_size]
        fft_batch = np.fft.fftshift(np.fft.fft2(batch), axes=(-2, -1)).astype(np.complex64)
        fft_images.append(fft_batch)
    return np.concatenate(fft_images, axis=0)

# %%
x_train_fft = fft_batch(x_train_gray)
x_test_fft = fft_batch(x_test_gray)

# %%
model_simple_fft = models.Sequential()

model_simple_fft.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1)))
model_simple_fft.add(layers.MaxPooling2D((2, 2)))

model_simple_fft.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_simple_fft.add(layers.Dropout(0.3))
model_simple_fft.add(layers.MaxPooling2D((2, 2)))

model_simple_fft.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_simple_fft.add(layers.Dropout(0.3))
model_simple_fft.add(layers.MaxPooling2D((2, 2)))

model_simple_fft.add(layers.Flatten())
model_simple_fft.add(layers.Dense(512, activation='relu'))
model_simple_fft.add(layers.Dropout(0.3))
model_simple_fft.add(layers.Dense(6, activation='softmax'))

model_simple_fft.compile(optimizer='adam',
                     loss=tf.keras.losses.categorical_crossentropy,
                     metrics=['accuracy'])

# %%
batchSize = 32
epochsNum = 50

stopEarly = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Trening modelu
history = model_simple_fft.fit(x_train_fft,
                               y_train_oneHot,
                               batch_size=batchSize,
                               shuffle=True,
                                epochs=epochsNum,
                                validation_data=(x_test_fft, y_test_oneHot),
                                callbacks=[stopEarly])
# Out:
# Epoch 1/50
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 132/439 [========>.....................] - ETA: 1:33 - loss: 15.0812 - accuracy: 0.3572
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10136/1914025091.py in <module>
#       5
#       6 # Trening modelu
# ----> 7 history = model_simple_fft.fit(x_train_fft,
#       8                                y_train_oneHot,
#       9                                batch_size=batchSize,
#
# ~\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\src\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model_simple_fft.save("zapisane/model_simple_fft.h5")
model_simple_fft.save("zapisane/model_simple_fft.keras")

# %% [markdown]
# ## 2.6 AlexNet

# %%
for i, category in enumerate(folderlist):
    pictures = os.listdir(train_dir+"/"+category)
    for picture in pictures:
        img = plt.imread(train_dir+"/"+category+'/{0}'.format(picture),0)
        img_resized = resize(img, (227, 227))  # Zmiana rozmiaru obrazów
        x_train.append(img_resized)
        y_train.append(i)

print("Train data:")
print("x_train: "+str(len(x_train))) 
print("y_train: "+str(len(y_train)))
# Out:
# Train data:
# x_train: 14034
# y_train: 14034

# %%
for i, category in enumerate(folderlist):
    pictures = os.listdir(test_dir+"/"+category)
    for picture in pictures:
        img = plt.imread(test_dir+"/"+category+'/{0}'.format(picture),0)
        img_resized = resize(img, (227, 227))  # Zmiana rozmiaru obrazów
        x_test.append(img_resized)
        y_test.append(i)

print("Test data:")
print("x_test: "+str(len(x_test)))
print("y_test: "+str(len(y_test)))
# Out:
# Test data:
# x_test: 3000
# y_test: 3000

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential

# %%
model_AlexNet=models.Sequential()
model_AlexNet.add(Input(shape=(228, 228, 3)))

model_AlexNet.add(Conv2D(32,kernel_size=(5,5),activation='relu'))
model_AlexNet.add(MaxPooling2D(2,2))

model_AlexNet.add(Conv2D(32,kernel_size=(5,5),activation='relu'))
model_AlexNet.add(MaxPooling2D(2,2))

model_AlexNet.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model_AlexNet.add(MaxPooling2D(2,2))

model_AlexNet.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model_AlexNet.add(MaxPooling2D(2,2))

model_AlexNet.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model_AlexNet.add(MaxPooling2D(2,2))

model_AlexNet.add(Flatten())
model_AlexNet.add(Dense(units=1024,activation='relu'))
model_AlexNet.add(Dropout(0.20))
model_AlexNet.add(Dense(124,activation='relu'))
model_AlexNet.add(Dropout(0.20))

model_AlexNet.add(layers.Dense(6, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model_AlexNet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batchSize = 32
epochsNum = 65

stopEarly = EarlyStopping(monitor='val_accuracy' , patience=5, restore_best_weights=True)

history = model_AlexNet.fit(x_train_norm,
                   y_train_oneHot,
                   batch_size=batchSize,
                   shuffle=True,
                   epochs=epochsNum,
                   validation_data=(x_test_norm, y_test_oneHot),
                   callbacks=[stopEarly])
# Out:
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/65
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 439/439 [==============================] - 214s 456ms/step - loss: 1.1080 - accuracy: 0.5411 - val_loss: 0.8828 - val_accuracy: 0.6657
# Epoch 2/65
# 439/439 [==============================] - 160s 365ms/step - loss: 0.8137 - accuracy: 0.6860 - val_loss: 0.7295 - val_accuracy: 0.7130
# Epoch 3/65
# 439/439 [==============================] - 137s 313ms/step - loss: 0.6601 - accuracy: 0.7570 - val_loss: 0.6385 - val_accuracy: 0.7597
# Epoch 4/65
# 439/439 [==============================] - 137s 311ms/step - loss: 0.5692 - accuracy: 0.7967 - val_loss: 0.7098 - val_accuracy: 0.7460
# Epoch 5/65
# 439/439 [==============================] - 137s 311ms/step - loss: 0.5007 - accuracy: 0.8199 - val_loss: 0.5202 - val_accuracy: 0.8183
# Epoch 6/65
# 439/439 [==============================] - 137s 312ms/step - loss: 0.4413 - accuracy: 0.8429 - val_loss: 0.5034 - val_accuracy: 0.8253
# Epoch 7/65
# 439/439 [==============================] - 137s 312ms/step - loss: 0.3831 - accuracy: 0.8620 - val_loss: 0.5218 - val_accuracy: 0.8227
# Epoch 8/65
# 439/439 [==============================] - 138s 314ms/step - loss: 0.3237 - accuracy: 0.8857 - val_loss: 0.5194 - val_accuracy: 0.8243
# Epoch 9/65
# 439/439 [==============================] - 138s 315ms/step - loss: 0.2895 - accuracy: 0.8979 - val_loss: 0.5825 - val_accuracy: 0.8180
# Epoch 10/65
# 439/439 [==============================] - 137s 311ms/step - loss: 0.2528 - accuracy: 0.9108 - val_loss: 0.6095 - val_accuracy: 0.8080
# Epoch 11/65
# 439/439 [==============================] - 137s 312ms/step - loss: 0.2180 - accuracy: 0.9207 - val_loss: 0.7112 - val_accuracy: 0.8083

# %%
model_AlexNet.save("zapisane/model_AlexNet.h5")
model_AlexNet.save("zapisane/model_AlexNet.keras")
# Out:
# C:\Users\Kacper\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 3. Wyniki uczenia poszczególnych modeli

# %%
plot_training_history(history_simple, filename='training_history_model_simple.png')

# %%
import matplotlib.pyplot as plt

def plot_accuracy(epochsNum, acc, val_acc, filename=None):
    plt.figure(figsize=(6, 4))
    plt.plot(epochsNum, acc, 'r', label="Train accuracy")
    plt.plot(epochsNum, val_acc, 'b', label="Validation accuracy")
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title("Training and Validation Accuracy")
    plt.legend(loc='lower right')
    plt.grid(True)

    if filename:
        plt.savefig(filename)
    plt.show()

def plot_loss(epochsNum, loss, val_loss, filename=None):
    plt.figure(figsize=(6, 4))
    plt.plot(epochsNum, loss, 'r', label="Train loss")
    plt.plot(epochsNum, val_loss, 'b', label="Validation loss")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title("Training and Validation Loss")
    plt.legend(loc='upper right')
    plt.grid(True)

    if filename:
        plt.savefig(filename)
    plt.show()

def plot_training_history(history, accuracy_filename=None, loss_filename=None):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochsNum = range(1, len(acc) + 1)

    # Plot accuracy
    plot_accuracy(epochsNum, acc, val_acc, accuracy_filename)
    
    # Plot loss
    plot_loss(epochsNum, loss, val_loss, loss_filename)

# %%
plot_training_history(history_bigger, accuracy_filename='accuracy_training_history_model_bigger.png', loss_filename='loss_training_history_model_bigger.png')

# %%
plot_training_history(history_simple, accuracy_filename='accuracy_training_history_model_simple.png', loss_filename='loss_training_history_model_simple.png')

# %%
plot_training_history(history_modify, accuracy_filename='accuracy_training_history_model_modify.png', loss_filename='loss_training_history_model_modify.png')

# %%
plot_training_history(history, accuracy_filename='accuracy_training_history_AlexNet.png', loss_filename='loss_training_history_AlexNet.png')
